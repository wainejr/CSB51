# %%
# !pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-1.1.3-cp38-cp38-manylinux1_x86_64.whl (9.3 MB)
#      |████████████████████████████████| 9.3 MB 6.2 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/decioaguiar/miniconda3/lib/python3.8/site-packages (from pandas) (2.8.1)
# Requirement already satisfied: numpy>=1.15.4 in /home/decioaguiar/miniconda3/lib/python3.8/site-packages (from pandas) (1.19.1)
# Collecting pytz>=2017.2
#   Downloading pytz-2020.1-py2.py3-none-any.whl (510 kB)
#      |████████████████████████████████| 510 kB 3.7 MB/s eta 0:00:01
# Requirement already satisfied: six>=1.5 in /home/decioaguiar/miniconda3/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas) (1.14.0)
# Installing collected packages: pytz, pandas
# Successfully installed pandas-1.1.3 pytz-2020.1

# %%
import pandas as pd

daily = pd.read_csv('http://tiny.cc/idb-traffic-daily')
weekly = pd.read_csv('http://tiny.cc/idb-traffic-weekly')
metadata = pd.read_csv('http://tiny.cc/idb-traffic-metadata')

# %%
daily[daily['region_name'] == 'Fortaleza']
# Out:
#                  last_updated_utc region_slug region_name country_name  \
# 254    2020-10-19 11:49:34.602000   fortaleza   Fortaleza       Brazil
# 255    2020-10-19 11:49:34.602000   fortaleza   Fortaleza       Brazil
# 256    2020-10-19 11:49:34.602000   fortaleza   Fortaleza       Brazil
# 257    2020-10-19 11:49:34.602000   fortaleza   Fortaleza       Brazil
# 258    2020-10-19 11:49:34.602000   fortaleza   Fortaleza       Brazil
# ...                           ...         ...         ...          ...
# 22736  2020-10-19 11:49:34.602000   fortaleza   Fortaleza       Brazil
# 22737  2020-10-19 11:49:34.602000   fortaleza   Fortaleza       Brazil
# 22738  2020-10-19 11:49:34.602000   fortaleza   Fortaleza       Brazil
# 22739  2020-10-19 11:49:34.602000   fortaleza   Fortaleza       Brazil
# 22740  2020-10-19 11:49:34.602000   fortaleza   Fortaleza       Brazil
#
#       country_iso_code country_idb_code region_type  population  \
# 254                 BR               BR        city   3316343.0
# 255                 BR               BR        city   3316343.0
# 256                 BR               BR        city   3316343.0
# 257                 BR               BR        city   3316343.0
# 258                 BR               BR        city   3316343.0
# ...                ...              ...         ...         ...
# 22736               BR               BR        city   3316343.0
# 22737               BR               BR        city   3316343.0
# 22738               BR               BR        city   3316343.0
# 22739               BR               BR        city   3316343.0
# 22740               BR               BR        city   3316343.0
#
#                 timezone  month  day  dow  expected_2019  ratio_19  ratio_20  \
# 254    America/Fortaleza      4   29    3              1         1  0.232628
# 255    America/Fortaleza      6   10    3              1         1  0.425194
# 256    America/Fortaleza      3   11    3              1         1  0.935602
# 257    America/Fortaleza      3   18    3              1         1  0.435737
# 258    America/Fortaleza      7   15    3              1         1  0.511319
# ...                  ...    ...  ...  ...            ...       ...       ...
# 22736  America/Fortaleza     10   11    7              1         1  0.936258
# 22737  America/Fortaleza      5   10    7              1         1  0.456510
# 22738  America/Fortaleza      8   16    7              1         1  0.980735
# 22739  America/Fortaleza      9    6    7              1         1  1.004068
# 22740  America/Fortaleza      8    2    7              1         1  0.994792
#
#              tcp
# 254   -76.737246
# 255   -57.480615
# 256    -6.439790
# 257   -56.426313
# 258   -48.868147
# ...          ...
# 22736  -6.374160
# 22737 -54.348977
# 22738  -1.926504
# 22739   0.406777
# 22740  -0.520801
#
# [224 rows x 16 columns]

# %%
weekly.head()
# Out:
#              last_updated_utc   region_slug   region_name country_name  \
# 0  2020-10-19 11:48:53.469000  barranquilla  Barranquilla     Colombia
# 1  2020-10-19 11:48:53.469000  barranquilla  Barranquilla     Colombia
# 2  2020-10-19 11:48:53.469000  barranquilla  Barranquilla     Colombia
# 3  2020-10-19 11:48:53.469000  barranquilla  Barranquilla     Colombia
# 4  2020-10-19 11:48:53.469000  barranquilla  Barranquilla     Colombia
#
#   country_iso_code country_idb_code region_type  population        timezone  \
# 0               CO               CO        city   1931750.0  America/Bogota
# 1               CO               CO        city   1931750.0  America/Bogota
# 2               CO               CO        city   1931750.0  America/Bogota
# 3               CO               CO        city   1931750.0  America/Bogota
# 4               CO               CO        city   1931750.0  America/Bogota
#
#    week_number  min_month  min_day  max_month  max_day  expected_2019  \
# 0           13          3       23          3       29              1
# 1           40          9       28         10        4              1
# 2           42         10       12         10       18              1
# 3           22          5       25          5       31              1
# 4           18          4       27          5        3              1
#
#    ratio_19  ratio_20        tcp
# 0         1  0.057897 -94.210305
# 1         1  0.456310 -54.369018
# 2         1  0.433903 -56.609692
# 3         1  0.154346 -84.565446
# 4         1  0.070287 -92.971310

# %%
from utils import connect_athena
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-18-44d014018c80> in <module>
# ----> 1 from utils import connect_athena
#
# /mnt/c/Users/decio/Documents/icd202002/02 - Analise exploratoria/utils.py in <module>
#       2 from jinja2 import Template
#       3 import time
# ----> 4 import yaml
#       5 from pathlib import Path
#       6 import logging
#
# ModuleNotFoundError: No module named 'yaml'

# %%
# !pip install yaml
# Out:
# ERROR: Could not find a version that satisfies the requirement yaml (from versions: none)
# ERROR: No matching distribution found for yaml
